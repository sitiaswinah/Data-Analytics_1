# %% [markdown]
# # **TASK DAY 1**

# %% [markdown]
# **Task 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('sephora_website_dataset.csv')

# %%
df.head()
# Out:
#         id           brand   category                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  number_of_reviews  love  price  value_price  ...  \
# 0  5 x 0.16oz/5mL     4.0                  4  3002   66.0         75.0  ...
# 1   0.7 oz/ 20 mL     4.5                 76  2700   66.0         66.0  ...
# 2    5 oz/ 148 mL     4.5                 26  2600  180.0        180.0  ...
# 3   2.5 oz/ 74 mL     4.5                 23  2900  120.0        120.0  ...
# 4  5 x 0.16oz/5mL     3.5                  2   943   72.0         80.0  ...
#
#   MarketingFlags  MarketingFlags_content  \
# 0           True             online only
# ...

# %%
#menampilkan nilai quantitatif

df.describe()
# Out:
#                  id       rating  number_of_reviews          love  \
# count  9.168000e+03  9168.000000        9168.000000  9.168000e+03
# mean   1.962952e+06     3.990020         282.139180  1.627859e+04
# std    3.859714e+05     1.007707         890.642028  4.260651e+04
# min    5.000000e+01     0.000000           0.000000  0.000000e+00
# 25%    1.819453e+06     4.000000          10.000000  1.600000e+03
# 50%    2.072354e+06     4.000000          46.000000  4.800000e+03
# 75%    2.230591e+06     4.500000         210.000000  1.380000e+04
# max    2.359685e+06     5.000000       19000.000000  1.300000e+06
#
#              price  value_price  online_only    exclusive  limited_edition  \
# count  9168.000000   9168.00000  9168.000000  9168.000000      9168.000000
# mean     50.063237     51.82359     0.234839     0.264725         0.091841
# std      47.164989     49.45902     0.423921     0.441211         0.288817
# ...

# %%
df['price'].mean()
# Out:
# 50.06323734729494

# %%
df['price'].median()
# Out:
# 35.0

# %%
df['price'].mode()[0]
# Out:
# 25.0

# %%
df['price'].min()
# Out:
# 2.0

# %%
df['price'].max()
# Out:
# 549.0

# %% [markdown]
# # **TASK DAY 2**

# %% [markdown]
# **Task 1**

# %% [markdown]
# Dari dataset lain yang mempunyai missing value, cek distribusi nya kemudian imputation

# %%
df = pd.read_csv('ikea.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   item_id                   name       category   price  \
# 0           0  90420332               FREKVENS  Bar furniture   265.0
# 1           1    368814              NORDVIKEN  Bar furniture   995.0
# 2           2   9333523  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0
# 3           3  80155205                   STIG  Bar furniture    69.0
# 4           4  30180504                NORBERG  Bar furniture   225.0
#
#       old_price  sellable_online  \
# 0  No old price             True
# 1  No old price            False
# 2  No old price            False
# 3  No old price             True
# 4  No old price             True
#
#                                                 link other_colors  \
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...           No
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...           No
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...           No
# 3  https://www.ikea.com/sa/en/p/stig-bar-stool-wi...          Yes
# ...

# %%
# melihat info data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3694 non-null   int64
#  1   item_id            3694 non-null   int64
#  2   name               3694 non-null   object
#  3   category           3694 non-null   object
#  4   price              3694 non-null   float64
#  5   old_price          3694 non-null   object
#  6   sellable_online    3694 non-null   bool
#  7   link               3694 non-null   object
#  8   other_colors       3694 non-null   object
#  9   short_description  3694 non-null   object
#  10  designer           3694 non-null   object
#  11  depth              2231 non-null   float64
#  12  height             2706 non-null   float64
#  13  width              3105 non-null   float64
# dtypes: bool(1), float64(4), int64(2), object(7)
# memory usage: 378.9+ KB

# %%
df.depth.plot(kind='hist');

# %%
df.height.plot(kind='hist');

# %%
df.width.plot(kind='hist');

# %%
val = df.depth.median()
df['depth'] = df.depth.fillna(val)

# %%
val = df.height.median()
df['height'] = df.depth.fillna(val)

# %%
val = df.width.median()
df['width'] = df.depth.fillna(val)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3694 entries, 0 to 3693
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3694 non-null   int64
#  1   item_id            3694 non-null   int64
#  2   name               3694 non-null   object
#  3   category           3694 non-null   object
#  4   price              3694 non-null   float64
#  5   old_price          3694 non-null   object
#  6   sellable_online    3694 non-null   bool
#  7   link               3694 non-null   object
#  8   other_colors       3694 non-null   object
#  9   short_description  3694 non-null   object
#  10  designer           3694 non-null   object
#  11  depth              3694 non-null   float64
#  12  height             3694 non-null   float64
#  13  width              3694 non-null   float64
# dtypes: bool(1), float64(4), int64(2), object(7)
# memory usage: 378.9+ KB

# %% [markdown]
# **Task 2**

# %%
df = pd.read_csv('Concert Tours.csv')

# %%
df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      object
#  2   All Time Peak                     6 non-null      object
#  3   Actual gross                      20 non-null     object
#  4   Adjusted gross (in 2022 dollars)  20 non-null     object
#  5   Artist                            20 non-null     object
#  6   Tour title                        20 non-null     object
#  7   Year(s)                           20 non-null     object
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     object
#  10  Ref.                              20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
df.shape[0]
# Out:
# 20

# %%
df['Peak'].isna().sum()
# Out:
# 11

# %%
df['Peak'].isna().sum()/df.shape[0]
# Out:
# 0.55

# %%
df.Peak.value_counts()
# Out:
# Peak
# 1        2
# 2[4]     2
# 1[4]     1
# 2[7]     1
# 2[10]    1
# 1[20]    1
# 2[c]     1
# Name: count, dtype: int64

# %%
df.drop('Peak', axis=1, inplace = True)

# %%
df['Rating'].isna().sum()
# Out:
# 1474

# %%
df['Rating'].isna().sum()/df.shape[0]
# Out:
# 0.13596531685268887

# %% [markdown]
# df = pd.read_csv('user.csv')

# %% [markdown]
# **Task 2**

# %%
df = pd.read_csv('users.csv')

# %%
df.head()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
df.shape[0]
# Out:
# 500

# %%
df['churn_date'].isna().sum()
# Out:
# 466

# %%
df['churn_date'].isna().sum()/df.shape[0]
# Out:
# 0.932

# %%
df.churn_date.value_counts()
# Out:
# churn_date
# 2018-12-18    3
# 2018-12-31    2
# 2018-11-14    2
# 2018-12-19    2
# 2018-12-15    1
# 2018-11-18    1
# 2018-09-17    1
# 2018-12-10    1
# 2018-08-19    1
# 2018-11-21    1
# 2018-09-01    1
# 2018-12-26    1
# 2018-08-16    1
# 2018-10-22    1
# 2018-10-03    1
# 2018-10-13    1
# 2018-07-31    1
# 2018-11-16    1
# 2018-11-30    1
# 2018-12-22    1
# 2018-11-29    1
# 2018-12-27    1
# 2018-12-12    1
# 2018-11-11    1
# 2018-11-24    1
# 2018-10-07    1
# 2018-12-30    1
# 2018-09-07    1
# 2018-09-18    1
# Name: count, dtype: int64

# %%
df.drop('churn_date', axis=1, inplace = True)

# %% [markdown]
# # **Task Day 3**

# %% [markdown]
# **Task 1**

# %% [markdown]
# Cek missing value (data categorical)
#
# setelah itu di olah seperti di manipulasi atau di drop atau di olah menjadi lain nya

# %% [markdown]
# Cek kolom Ingredient

# %%
df = pd.read_csv('sephora_website_dataset.csv')

# %%
df.head()
# Out:
#         id           brand   category                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
# 2  1417567  Acqua Di Parma    Perfume                Arancia di Capri
# 3  1417617  Acqua Di Parma    Perfume                Mirto di Panarea
# 4  2218766  Acqua Di Parma  Fragrance           Colonia Miniature Set
#
#              size  rating  number_of_reviews  love  price  value_price  ...  \
# 0  5 x 0.16oz/5mL     4.0                  4  3002   66.0         75.0  ...
# 1   0.7 oz/ 20 mL     4.5                 76  2700   66.0         66.0  ...
# 2    5 oz/ 148 mL     4.5                 26  2600  180.0        180.0  ...
# 3   2.5 oz/ 74 mL     4.5                 23  2900  120.0        120.0  ...
# 4  5 x 0.16oz/5mL     3.5                  2   943   72.0         80.0  ...
#
#   MarketingFlags  MarketingFlags_content  \
# 0           True             online only
# ...

# %%
df.shape[0]
# Out:
# 9168

# %%
df['ingredients'].isna().sum()/df.shape[0]
# Out:
# 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9168 non-null   int64
#  1   brand                   9168 non-null   object
#  2   category                9168 non-null   object
#  3   name                    9168 non-null   object
#  4   size                    9168 non-null   object
#  5   rating                  9168 non-null   float64
#  6   number_of_reviews       9168 non-null   int64
#  7   love                    9168 non-null   int64
#  8   price                   9168 non-null   float64
#  9   value_price             9168 non-null   float64
#  10  URL                     9168 non-null   object
#  11  MarketingFlags          9168 non-null   bool
#  12  MarketingFlags_content  9168 non-null   object
#  13  options                 9168 non-null   object
# ...

# %% [markdown]
# Persentase <70% dan data masih cukup informatif dengan dataset product info sehingga akan dilakukan imputan

# %%
# tampilkan proporsi data

df.ingredients.value_counts()
# Out:
# ingredients
# ...

# %%
# apabila terlalu banyak data unique & tidak terlalu informatif dapat dihapus column nya

df.drop('ingredients', axis=1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9168 non-null   int64
#  1   brand                   9168 non-null   object
#  2   category                9168 non-null   object
#  3   name                    9168 non-null   object
#  4   size                    9168 non-null   object
#  5   rating                  9168 non-null   float64
#  6   number_of_reviews       9168 non-null   int64
#  7   love                    9168 non-null   int64
#  8   price                   9168 non-null   float64
#  9   value_price             9168 non-null   float64
#  10  URL                     9168 non-null   object
#  11  MarketingFlags          9168 non-null   bool
#  12  MarketingFlags_content  9168 non-null   object
#  13  options                 9168 non-null   object
# ...

# %% [markdown]
# **Task 2**

# %% [markdown]
# Memanipulasi Data

# %%
# load new data

df = pd.read_csv('Samsung.csv')

# %%
df.head()
# Out:
#                                           name  ratings  price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   9499
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  10499
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  10499
# 3  SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  10499
# 4    SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  15499
#
#                                               imgURL  camera      display  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 1  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 2  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 3  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 4  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
#
#    battery  storage  ram                processor  android_version
# 0     6000       64    4            not mentioned               12
# ...

# %% [markdown]
# Menambahkan kolom baru berdasarkan karakteristik yang perlu ditunjukan melalui kolom baru yang diambil dari 2 kolom pada dataset

# %%
df['phone']=df['storage']+df['ram']

# %%
df['phone'][df['phone']>68]='standart'
df['phone'][df['phone']==68]='worth to buy'
# Out:
# C:\Users\Win 10\AppData\Local\Temp\ipykernel_11140\1127118907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['phone'][df['phone']>68]='standart'
# C:\Users\Win 10\AppData\Local\Temp\ipykernel_11140\1127118907.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'standart' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df['phone'][df['phone']>68]='standart'

# %%
df.head()
# Out:
#                                           name  ratings  price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   9499
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  10499
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  10499
# 3  SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  10499
# 4    SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  15499
#
#                                               imgURL  camera      display  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 1  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 2  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 3  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
# 4  https://rukminim2.flixcart.com/image/312/312/x...      50  other_types
#
#    battery  storage  ram                processor  android_version  \
# 0     6000       64    4            not mentioned               12
# ...

# %% [markdown]
# **Task 3**

# %%
df.category[df['rating']==1].value_counts()
# Out:
# category
# Candles                      3
# Candles & Home Scents        3
# Shampoo                      2
# Hair                         2
# Eye Brushes                  2
# Perfume                      1
# Lotions & Oils               1
# Face Sunscreen               1
# Nail                         1
# Value & Gift Sets            1
# Mini Size                    1
# Rollerballs & Travel Size    1
# Moisturizers                 1
# Foundation                   1
# Perfume Gift Sets            1
# Face Serums                  1
# Name: count, dtype: int64

# %%
df.category[df['rating']==1].value_counts().plot(kind='bar');

# %% [markdown]
# # **Task Day 4**

# %%
df = pd.read_csv('ikea.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   item_id                   name       category   price  \
# 0           0  90420332               FREKVENS  Bar furniture   265.0
# 1           1    368814              NORDVIKEN  Bar furniture   995.0
# 2           2   9333523  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0
# 3           3  80155205                   STIG  Bar furniture    69.0
# 4           4  30180504                NORBERG  Bar furniture   225.0
#
#       old_price  sellable_online  \
# 0  No old price             True
# 1  No old price            False
# 2  No old price            False
# 3  No old price             True
# 4  No old price             True
#
#                                                 link other_colors  \
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...           No
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...           No
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...           No
# 3  https://www.ikea.com/sa/en/p/stig-bar-stool-wi...          Yes
# ...

# %% [markdown]
# **Task 1**

# %%
df_slice = df[['category', 'sellable_online', 'item_id']]
slice_pivot = df_slice.pivot_table(index=['category'], columns=['sellable_online'], \
                                    aggfunc=np.size, fill_value=0)

# %%
slice_pivot
# Out:
#                                      item_id
# sellable_online                        False True
# category
# Bar furniture                              3    44
# Beds                                       3   205
# Bookcases & shelving units                 1   547
# Cabinets & cupboards                       1   291
# Café furniture                             0    26
# Chairs                                     4   477
# Chests of drawers & drawer units           0   125
# Children's furniture                       5   119
# Nursery furniture                          4    93
# Outdoor furniture                          0   216
# Room dividers                              0    13
# Sideboards, buffets & console tables       0    23
# Sofas & armchairs                          1   427
# TV & media furniture                       1   189
# Tables & desks                             4   608
# Trolleys                                   1    27
# ...

# %%
df_slice = df[['category', 'other_colors', 'sellable_online', 'item_id']]
slice_pivot = df_slice.pivot_table(index=['category', 'other_colors'], columns=['sellable_online'], \
                                    aggfunc=np.size, fill_value=0)

# %%
slice_pivot
# Out:
#                                                   item_id
# sellable_online                                     False True
# category                             other_colors
# Bar furniture                        No                 3    39
#                                      Yes                0     5
# Beds                                 No                 2   113
#                                      Yes                1    92
# Bookcases & shelving units           No                 1   318
#                                      Yes                0   229
# Cabinets & cupboards                 No                 1   104
#                                      Yes                0   187
# Café furniture                       No                 0    21
#                                      Yes                0     5
# Chairs                               No                 4   378
#                                      Yes                0    99
# ...

# %% [markdown]
# **Task 2**

# %% [markdown]
# memberikan group by pada kolom yang meksens

# %%
df[['price', 'sellable_online']].groupby('sellable_online').mean()
# Out:
#                        price
# sellable_online
# False             445.571429
# True             1083.040344

# %%
# crosstab secara default menghitung frekuensinya

pd.crosstab(df.category, df.sellable_online)
# Out:
# sellable_online                       False  True
# category
# Bar furniture                             3     44
# Beds                                      3    205
# Bookcases & shelving units                1    547
# Cabinets & cupboards                      1    291
# Café furniture                            0     26
# Chairs                                    4    477
# Chests of drawers & drawer units          0    125
# Children's furniture                      5    119
# Nursery furniture                         4     93
# Outdoor furniture                         0    216
# Room dividers                             0     13
# Sideboards, buffets & console tables      0     23
# Sofas & armchairs                         1    427
# TV & media furniture                      1    189
# Tables & desks                            4    608
# Trolleys                                  1     27
# Wardrobes                                 0    236

# %% [markdown]
# **Task 3**

# %% [markdown]
# - Get dummies
# - sort
# - rename

# %%
pd.get_dummies(df.category, 'sellable_online')
# Out:
#       sellable_online_Bar furniture  sellable_online_Beds  \
# 0                              True                 False
# 1                              True                 False
# 2                              True                 False
# 3                              True                 False
# 4                              True                 False
# ...                             ...                   ...
# 3689                          False                 False
# 3690                          False                 False
# 3691                          False                 False
# 3692                          False                 False
# 3693                          False                 False
#
#       sellable_online_Bookcases & shelving units  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# ...

# %%
df.sort_values('price', ascending=False)
# Out:
#       Unnamed: 0   item_id        name                    category   price  \
# 2344        2344  79277632     LIDHULT           Sofas & armchairs  9585.0
# 190          190  29277639     LIDHULT                        Beds  9585.0
# 2559        2559  89256610     GRÖNLID           Sofas & armchairs  8900.0
# 118          118  89186778  KONGSFJORD                        Beds  8551.0
# 2455        2455  49269153  LANDSKRONA           Sofas & armchairs  8495.0
# ...          ...       ...         ...                         ...     ...
# 1834        1834     91415     TROFAST        Children's furniture     5.0
# 1900        1900  70091412     TROFAST           Nursery furniture     5.0
# 389          389  80336433     GUBBARP  Bookcases & shelving units     3.0
# 879          879  80336433     GUBBARP        Cabinets & cupboards     3.0
# 3349        3349  80336433     GUBBARP        TV & media furniture     3.0
#
#          old_price  sellable_online  \
# ...

# %%
df.rename(columns={'categori': 'categori_item', 'link': 'link_item'})
# Out:
#       Unnamed: 0   item_id                   name       category   price  \
# 0              0  90420332               FREKVENS  Bar furniture   265.0
# 1              1    368814              NORDVIKEN  Bar furniture   995.0
# 2              2   9333523  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0
# 3              3  80155205                   STIG  Bar furniture    69.0
# 4              4  30180504                NORBERG  Bar furniture   225.0
# ...          ...       ...                    ...            ...     ...
# 3689        3689  99157902                ELVARLI      Wardrobes   750.0
# 3690        3690   9158152                ELVARLI      Wardrobes  1572.0
# 3691        3691  59157541                ELVARLI      Wardrobes   924.0
# 3692        3692  89157573                ELVARLI      Wardrobes  2745.0
# 3693        3693  69157376                ELVARLI      Wardrobes  1231.0
#
#          old_price  sellable_online  \
# 0     No old price             True
# ...

# %% [markdown]
# **Task 4**

# %% [markdown]
# Concat

# %%
df1 = df[['item_id', 'name', 'link']][0:3]

# %%
df1
# Out:
#     item_id                   name  \
# 0  90420332               FREKVENS
# 1    368814              NORDVIKEN
# 2   9333523  NORDVIKEN / NORDVIKEN
#
#                                                 link
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...

# %%
df2 = df[['item_id', 'name', 'link']][0:8]

# %%
df2
# Out:
#     item_id                   name  \
# 0  90420332               FREKVENS
# 1    368814              NORDVIKEN
# 2   9333523  NORDVIKEN / NORDVIKEN
# 3  80155205                   STIG
# 4  30180504                NORBERG
# 5  10122647                 INGOLF
# 6  70404875               FRANKLIN
# 7  60155602                DALFRED
#
#                                                 link
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...
# 3  https://www.ikea.com/sa/en/p/stig-bar-stool-wi...
# 4  https://www.ikea.com/sa/en/p/norberg-wall-moun...
# 5  https://www.ikea.com/sa/en/p/ingolf-bar-stool-...
# 6  https://www.ikea.com/sa/en/p/franklin-bar-stoo...
# 7  https://www.ikea.com/sa/en/p/dalfred-bar-stool...

# %%
df_concat = pd.concat ([df1, df2])

df_concat
# Out:
#     item_id                   name  \
# 0  90420332               FREKVENS
# 1    368814              NORDVIKEN
# 2   9333523  NORDVIKEN / NORDVIKEN
# 0  90420332               FREKVENS
# 1    368814              NORDVIKEN
# 2   9333523  NORDVIKEN / NORDVIKEN
# 3  80155205                   STIG
# 4  30180504                NORBERG
# 5  10122647                 INGOLF
# 6  70404875               FRANKLIN
# 7  60155602                DALFRED
#
#                                                 link
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...
# 3  https://www.ikea.com/sa/en/p/stig-bar-stool-wi...
# 4  https://www.ikea.com/sa/en/p/norberg-wall-moun...
# 5  https://www.ikea.com/sa/en/p/ingolf-bar-stool-...
# ...

# %% [markdown]
# # **Task Day 5**

# %% [markdown]
# # Proses Data Cleaning

# %%
# load new data

df = pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Melihat info dataset mengenai missing values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Melihat jumlah non null dari data

df.notnull().sum()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %% [markdown]
# **Cleaning column Rating**

# %%
#menampilkan visualisasi columnnya

df.Rating.plot(kind='hist');

# %%
#cleaning

val = df.Rating.median()
df['Rating'] = df.Rating.fillna(val)

# %%
#menampilkan info dataset untuk melihat apakah column Rating sudah ter imputation

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# **Cleaning column Type**

# %%
df.shape[0]
# Out:
# 10841

# %%
# #menghitung persentase

df['Type'].isna().sum()/df.shape[0]
# Out:
# 9.224241306152569e-05

# %%
df.Type.value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# Note : Column Type memiliki data yang jelas (berisikan tipe aplikasi berbayar dan gratis serta hanya ada 1 missing value, jai dapat dipertahankan

# %%
#jumlah data missing

df.Type.isna().sum()
# Out:
# 1

# %%
#cleaning

val = df.Type.mode().values[0]
df['Type'] = df.Type.fillna(val)

# %%
#tampilkan proporsi data lagi

df.Type.value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
#cek apakah column Type sudah berubah

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Notes: column type dipertahankan karena missing value hanya 1 dan bukan data unique (isi data jelas)

# %% [markdown]
# **Cleaning column Content Rating**

# %% [markdown]
# Column Contet Rating

# %%
df['Content Rating'].isna().sum()/df.shape[0]
# Out:
# 9.224241306152569e-05

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
# jumlah data missing

df['Content Rating'].isna().sum()
# Out:
# 1

# %%
val = df['Content Rating'].mode().values[0]
df['Content Rating'] = df['Content Rating'].fillna(val)

# %%
# tampilkan proporsi data lagi

df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8715
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
#cek apkah kolom Content Rating sudah berubah

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Notes : Column Content Rating juga diprtahankan karena missing value hanya 1 dan bukan data unique (isi data jelas)

# %% [markdown]
# **Cleaning Coumn Current Ver**

# %%
df['Current Ver'].value_counts()
# Out:
# Current Ver
# Varies with device    1459
# 1.0                    809
# 1.1                    264
# 1.2                    178
# 2.0                    151
#                       ...
# 1.0.17.3905              1
# 15.1.2                   1
# 4.94.19                  1
# 1.1.11.11                1
# 2.0.148.0                1
# Name: count, Length: 2832, dtype: int64

# %% [markdown]
# termasuk kedalam data unique, dapat di drop

# %%
# jumlah data missing

df['Current Ver'].isna().sum()
# Out:
# 8

# %%
df['Current Ver'].isna().sum()/df.shape[0]
# Out:
# 0.0007379393044922055

# %%
# menghapus kolom

df.drop('Current Ver', axis=1, inplace = True)

# %%
# cek apakah kolom Current Ver sudah terhapus

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Android Ver     10838 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 1016.5+ KB

# %% [markdown]
# Notes : column current ver tidak dipertahankan karena termasuk data unique

# %% [markdown]
# **Cleaning column Android Ver**

# %%
df['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: count, dtype: int64

# %%
# menghapus kolom

df.drop('Android Ver', axis=1, inplace = True)

# %%
# cek apakah column Anroid sudah terhapus

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 931.8+ KB

# %% [markdown]
# # Data Manipultion

# %% [markdown]
# **Sort**

# %%
# Sorting berdasarkan 'Reviews' dari tertinggi ke terendah

df_sorted = df.sort_values(by='Reviews', ascending=False)

# %%
print(df_sorted.head())
# Out:
#                                     App  Category  Rating Reviews Size  \
# 2989             GollerCepte Live Score    SPORTS     4.2    9992  31M
# 4970       Ad Block REMOVER - NEED ROOT     TOOLS     3.3     999  91k
# 2723                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 2705                SnipSnap Coupon App  SHOPPING     4.2    9975  18M
# 3079  US Open Tennis Championships 2018    SPORTS     4.0    9971  33M
#
#         Installs  Type Price Content Rating    Genres       Last Updated
# 2989  1,000,000+  Free     0       Everyone    Sports       May 23, 2018
# 4970    100,000+  Free     0       Everyone     Tools  December 17, 2013
# 2723  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 2705  1,000,000+  Free     0       Everyone  Shopping   January 22, 2018
# 3079  1,000,000+  Free     0       Everyone    Sports       June 5, 2018

# %% [markdown]
# **Pivot Grafik**

# %%
# Membuat pivot grafik menggunakan pie chart untuk menampilkan distribusi 'Category'

import matplotlib.pyplot as plt

# %%
# Pivot Grafik (Pie Chart)

category_counts = df['Category'].value_counts()
plt.figure(figsize=(6, 6))
category_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Categories')
plt.ylabel('')
plt.show()

# %% [markdown]
# Notes : Gk yakin pake Pie Chart dan valuenya

# %% [markdown]
# **Filtering**

# %%
# menampilkn data rating aplikasi yang lebih besar dari 4

filtered_df = df[df['Rating'] > 4]
filtered_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# **Grouping**

# %%
 #groupby

df[['Type', 'Rating']].groupby('Type').mean()
# Out:
#          Rating
# Type
# 0     19.000000
# Free   4.201175
# Paid   4.273000

# %% [markdown]
# **Concat**

# %%
# Menggabungkan dua atau lebih objek data secara struktural

df1 = df[['App', 'Rating', 'Size']][0:5]
df1
# Out:
#                                                  App  Rating  Size
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1   19M
# 1                                Coloring book moana     3.9   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7  8.7M
# 3                              Sketch - Draw & Paint     4.5   25M
# 4              Pixel Draw - Number Art Coloring Book     4.3  2.8M

# %%
df2 = df[['App', 'Rating', 'Size']][5:10]
df2
# Out:
#                                        App  Rating  Size
# 5               Paper flowers instructions     4.4  5.6M
# 6  Smoke Effect Photo Maker - Smoke Editor     3.8   19M
# 7                         Infinite Painter     4.1   29M
# 8                     Garden Coloring Book     4.4   33M
# 9            Kids Paint Free - Drawing Fun     4.7  3.1M

# %%
df_concat = pd.concat ([df1, df2])
df_concat
# Out:
#                                                  App  Rating  Size
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1   19M
# 1                                Coloring book moana     3.9   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7  8.7M
# 3                              Sketch - Draw & Paint     4.5   25M
# 4              Pixel Draw - Number Art Coloring Book     4.3  2.8M
# 5                         Paper flowers instructions     4.4  5.6M
# 6            Smoke Effect Photo Maker - Smoke Editor     3.8   19M
# 7                                   Infinite Painter     4.1   29M
# 8                               Garden Coloring Book     4.4   33M
# 9                      Kids Paint Free - Drawing Fun     4.7  3.1M

# %% [markdown]
# **Merge**

# %%
# menggabungkan beberapa kolom tertentu yang dipilih.

df3 = df[['App', 'Rating', 'Size']][0:3]
df3
# Out:
#                                                  App  Rating  Size
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1   19M
# 1                                Coloring book moana     3.9   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7  8.7M

# %%
df4 = df[['App', 'Genres', 'Content Rating']][0:3]
df4
# Out:
#                                                  App  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                Coloring book moana
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#                       Genres Content Rating
# 0               Art & Design       Everyone
# 1  Art & Design;Pretend Play       Everyone
# 2               Art & Design       Everyone

# %%
df_merge = pd.merge(df3, df4, how="left", on=["App"])
df_merge
# Out:
#                                                  App  Rating  Size  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1   19M
# 1                                Coloring book moana     3.9   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7  8.7M
#
#                       Genres Content Rating
# 0               Art & Design       Everyone
# 1  Art & Design;Pretend Play       Everyone
# 2               Art & Design       Everyone
